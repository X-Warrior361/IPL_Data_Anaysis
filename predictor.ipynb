# %%
! pip install mysqlclient
# Out:
# Requirement already satisfied: mysqlclient in d:\ipl\venv\lib\site-packages (2.2.0)
# WARNING: You are using pip version 21.1.2; however, version 23.3.1 is available.
# You should consider upgrading via the 'D:\IPL\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import sqlalchemy
import pandas as pd
import numpy as np

# %%
engine = 'mysql+mysqldb://root:password@localhost:3306/ipl'   # Change according to your local database
conn = sqlalchemy.create_engine(engine)

# %%
sql = sqlalchemy.text("select * from all_matches")
df = pd.read_sql_query(sql, conn.connect())
df
# Out:
#         Match_Id  Innings  Ball                 Batting_Team  \
# 0         335982        1   0.1        Kolkata Knight Riders
# 1         335982        1   0.2        Kolkata Knight Riders
# 2         335982        1   0.3        Kolkata Knight Riders
# 3         335982        1   0.3        Kolkata Knight Riders
# 4         335982        1   0.4        Kolkata Knight Riders
# ...          ...      ...   ...                          ...
# 225785   1136605        2  18.2  Royal Challengers Bangalore
# 225786   1136605        2  18.3  Royal Challengers Bangalore
# 225787   1136605        2  18.4  Royal Challengers Bangalore
# 225788   1136605        2  18.5  Royal Challengers Bangalore
# 225789   1136605        2  18.6  Royal Challengers Bangalore
#
#                        Bowling_Team              Striker          Non_Striker  \
# 0       Royal Challengers Bangalore       Sourav Ganguly     Brendon McCullum
# 1       Royal Challengers Bangalore     Brendon McCullum       Sourav Ganguly
# 2       Royal Challengers Bangalore     Brendon McCullum       Sourav Ganguly
# 3       Royal Challengers Bangalore     Brendon McCullum       Sourav Ganguly
# 4       Royal Challengers Bangalore     Brendon McCullum       Sourav Ganguly
# ...                             ...                  ...                  ...
# 225785             Delhi Daredevils       AB de Villiers  Colin de Grandhomme
# 225786             Delhi Daredevils       AB de Villiers  Colin de Grandhomme
# 225787             Delhi Daredevils  Colin de Grandhomme       AB de Villiers
# 225788             Delhi Daredevils  Colin de Grandhomme       AB de Villiers
# 225789             Delhi Daredevils       AB de Villiers  Colin de Grandhomme
#
#                Bowler  Runs_off_bat  Extras  Wide  No_Ball  Leg_Bye  Bye  \
# 0       Praveen Kumar             0       1     0        0        1    0
# 1       Praveen Kumar             0       0     0        0        0    0
# 2       Praveen Kumar             0       1     1        0        0    0
# 3       Praveen Kumar             0       0     0        0        0    0
# 4       Praveen Kumar             0       0     0        0        0    0
# ...               ...           ...     ...   ...      ...      ...  ...
# 225785    Trent Boult             6       0     0        0        0    0
# 225786    Trent Boult             1       0     0        0        0    0
# 225787    Trent Boult             0       0     0        0        0    0
# 225788    Trent Boult             1       0     0        0        0    0
# 225789    Trent Boult             6       0     0        0        0    0
#
#         Penalty Wicket_Type Player_Dismissed Fielder
# 0             0        None             None    None
# 1             0        None             None    None
# 2             0        None             None    None
# 3             0        None             None    None
# 4             0        None             None    None
# ...         ...         ...              ...     ...
# 225785        0        None             None    None
# 225786        0        None             None    None
# 225787        0        None             None    None
# 225788        0        None             None    None
# 225789        0        None             None    None
#
# [225790 rows x 18 columns]
# Requirement already satisfied: pandas in d:\ipl\venv\lib\site-packages (from -r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: requests in d:\ipl\venv\lib\site-packages (from -r requirements.txt (line 2)) (2.28.1)
# Requirement already satisfied: bs4 in d:\ipl\venv\lib\site-packages (from -r requirements.txt (line 3)) (0.0.1)
# Requirement already satisfied: selenium in d:\ipl\venv\lib\site-packages (from -r requirements.txt (line 4)) (4.6.0)
# Requirement already satisfied: webdriver_manager in d:\ipl\venv\lib\site-packages (from -r requirements.txt (line 5)) (3.8.5)
# Collecting spacy
#   Downloading spacy-3.7.2-cp39-cp39-win_amd64.whl (12.2 MB)
# Collecting sqlalchemy
#   Using cached SQLAlchemy-2.0.22-cp39-cp39-win_amd64.whl (2.1 MB)
# Requirement already satisfied: pytz>=2020.1 in d:\ipl\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\ipl\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in d:\ipl\venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: six>=1.5 in d:\ipl\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\ipl\venv\lib\site-packages (from requests->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\ipl\venv\lib\site-packages (from requests->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\ipl\venv\lib\site-packages (from requests->-r requirements.txt (line 2)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ipl\venv\lib\site-packages (from requests->-r requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: beautifulsoup4 in d:\ipl\venv\lib\site-packages (from bs4->-r requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: trio-websocket~=0.9 in d:\ipl\venv\lib\site-packages (from selenium->-r requirements.txt (line 4)) (0.9.2)
# Requirement already satisfied: trio~=0.17 in d:\ipl\venv\lib\site-packages (from selenium->-r requirements.txt (line 4)) (0.22.0)
# Requirement already satisfied: outcome in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (22.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (1.0.4)
# Requirement already satisfied: sortedcontainers in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: sniffio in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: async-generator>=1.9 in d:\ipl\venv\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 4)) (1.10)
# Requirement already satisfied: pycparser in d:\ipl\venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: wsproto>=0.14 in d:\ipl\venv\lib\site-packages (from trio-websocket~=0.9->selenium->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\ipl\venv\lib\site-packages (from urllib3<1.27,>=1.21.1->requests->-r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\ipl\venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: packaging in d:\ipl\venv\lib\site-packages (from webdriver_manager->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: tqdm in d:\ipl\venv\lib\site-packages (from webdriver_manager->-r requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: python-dotenv in d:\ipl\venv\lib\site-packages (from webdriver_manager->-r requirements.txt (line 5)) (0.21.0)
# Collecting weasel<0.4.0,>=0.1.0
#   Downloading weasel-0.3.3-py3-none-any.whl (49 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Requirement already satisfied: setuptools in d:\ipl\venv\lib\site-packages (from spacy->-r requirements.txt (line 6)) (57.0.0)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp39-cp39-win_amd64.whl (483 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# Collecting thinc<8.3.0,>=8.1.8
#   Downloading thinc-8.2.1-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\ipl\venv\lib\site-packages (from packaging->webdriver_manager->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\ipl\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 6)) (4.8.0)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1
#   Downloading pydantic_core-2.10.1-cp39-none-win_amd64.whl (2.0 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp39-cp39-win_amd64.whl (6.6 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 455, in read
#     n = self.readinto(b)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 499, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\cli\base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\cli\req_command.py", line 204, in wrapper
#     return func(self, options, args)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\commands\install.py", line 318, in run
#     requirement_set = resolver.resolve(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 127, in resolve
#     result = self._result = resolver.resolve(
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 473, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 367, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_criteria_to_update(candidate)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 203, in _get_criteria_to_update
#     name, crit = self._merge_into_criterion(r, parent=candidate)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _merge_into_criterion
#     if not criterion.candidates:
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 139, in __bool__
#     return bool(self._sequence)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#     return any(self)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 129, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 33, in _iter_built
#     candidate = func()
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 200, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 306, in __init__
#     super().__init__(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 151, in __init__
#     self.dist = self._prepare()
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 234, in _prepare
#     dist = self._prepare_distribution()
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 317, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\operations\prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\operations\prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\operations\prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\network\download.py", line 157, in __call__
#     for chunk in chunks:
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\cli\progress_bars.py", line 152, in iter
#     for x in it:
#   File "D:\IPL\venv\lib\site-packages\pip\_internal\network\utils.py", line 62, in response_chunks
#     for chunk in response.raw.stream(
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\X Warrior\AppData\Local\Programs\Python\Python39\lib\contextlib.py", line 135, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "D:\IPL\venv\lib\site-packages\pip\_vendor\urllib3\response.py", line 455, in _error_catcher
#     raise ProtocolError("Connection broken: %r" % e, e)
# pip._vendor.urllib3.exceptions.ProtocolError: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# WARNING: You are using pip version 21.1.2; however, version 23.3.1 is available.
# You should consider upgrading via the 'D:\IPL\venv\Scripts\python.exe -m pip install --upgrade pip' command.
